# %% [markdown]
# # EDA Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
from datetime import datetime

# %%
Top5_stats = pd.read_csv('stats.csv')
Top5_stats
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 2               Liverpool  20.0    10.0   57.0            44.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# ...

# %%
Top_teams=pd.read_csv('results.csv')

# %%
Top_teams.groupby('season')['result'].count()
# Out:
# season
# 2006-2007    380
# 2007-2008    380
# 2008-2009    380
# 2009-2010    380
# 2010-2011    380
# 2011-2012    380
# 2012-2013    380
# 2013-2014    380
# 2014-2015    380
# 2015-2016    380
# 2016-2017    380
# 2017-2018    380
# Name: result, dtype: int64

# %%
Top_teams
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool         1.0         1.0      D
# 1               Arsenal       Aston Villa         1.0         1.0      D
# 2               Everton           Watford         2.0         1.0      H
# 3      Newcastle United    Wigan Athletic         2.0         1.0      H
# 4            Portsmouth  Blackburn Rovers         3.0         0.0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea         3.0         0.0      H
# 4556        Southampton   Manchester City         0.0         1.0      A
# 4557       Swansea City        Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur    Leicester City         5.0         4.0      H
# 4559    West Ham United           Everton         3.0         1.0      H
#
#          season
# 0     2006-2007
# 1     2006-2007
# 2     2006-2007
# 3     2006-2007
# ...

# %%
test=Top_teams[Top5_teams['season'] == '2009-2010']

# %%
test=test[(test['home_team']=='Manchester United') | (test['away_team']=='Manchester United')]

# %%
test
# Out:
#                     home_team                away_team  home_goals  \
# 1148        Manchester United          Birmingham City         1.0
# 1153                  Burnley        Manchester United         1.0
# 1161           Wigan Athletic        Manchester United         0.0
# 1172        Manchester United                  Arsenal         2.0
# 1183        Tottenham Hotspur        Manchester United         1.0
# 1192        Manchester United          Manchester City         4.0
# 1200               Stoke City        Manchester United         0.0
# 1210        Manchester United               Sunderland         2.0
# 1219        Manchester United         Bolton Wanderers         2.0
# 1233                Liverpool        Manchester United         2.0
# 1244        Manchester United         Blackburn Rovers         2.0
# 1255                  Chelsea        Manchester United         1.0
# 1263        Manchester United                  Everton         3.0
# ...

# %%
Top_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4560 entries, 0 to 4559
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   home_team   4560 non-null   object
#  1   away_team   4560 non-null   object
#  2   home_goals  4560 non-null   float64
#  3   away_goals  4560 non-null   float64
#  4   result      4560 non-null   object
#  5   season      4560 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 213.9+ KB

# %%
Top5_teams_D=Top_teams[Top_teams['result']== 'D']

# %%
Top5_teams_D
# Out:
#              home_team                 away_team  home_goals  away_goals  \
# 0     Sheffield United                 Liverpool         1.0         1.0
# 1              Arsenal               Aston Villa         1.0         1.0
# 10             Watford           West Ham United         1.0         1.0
# 13     Manchester City                Portsmouth         0.0         0.0
# 14    Blackburn Rovers                   Everton         1.0         1.0
# ...                ...                       ...         ...         ...
# 4525           Burnley  Brighton and Hove Albion         0.0         0.0
# 4540           Everton               Southampton         1.0         1.0
# 4541   Manchester City         Huddersfield Town         0.0         0.0
# 4545           Chelsea         Huddersfield Town         1.0         1.0
# 4549   West Ham United         Manchester United         0.0         0.0
#
#      result     season
# 0         D  2006-2007
# 1         D  2006-2007
# ...

# %%
Top5_teams_D.groupby('season')['result'].count()
# Out:
# season
# 2006-2007     98
# 2007-2008    100
# 2008-2009     97
# 2009-2010     96
# 2010-2011    111
# 2011-2012     93
# 2012-2013    108
# 2013-2014     78
# 2014-2015     93
# 2015-2016    107
# 2016-2017     84
# 2017-2018     99
# Name: result, dtype: int64

# %%
Top5_teams_D.groupby('season')['result'].count().mean()
# Out:
# 97.0

# %%
Top5_teams_D_H=Top5_teams_D.groupby(['home_team','season'])['result'].count().sort_values(ascending=False)

# %%
Top5_teams_D_A=Top5_teams_D.groupby(['away_team','season'])['result'].count().sort_values(ascending=False)

# %%
Top5_teams_D_H
# Out:
# home_team             season
# Manchester United     2016-2017    10
# West Bromwich Albion  2013-2014     9
#                       2017-2018     9
# Tottenham Hotspur     2010-2011     9
# Liverpool             2011-2012     9
#                                    ..
#                       2013-2014     1
# Chelsea               2009-2010     1
# Manchester City       2013-2014     1
#                       2011-2012     1
# Manchester United     2009-2010     1
# Name: result, Length: 237, dtype: int64

# %%
Top5_teams_D_A
# Out:
# away_team            season
# Aston Villa          2011-2012    10
# Manchester United    2010-2011    10
# Sunderland           2014-2015     9
# Manchester City      2009-2010     9
# Fulham               2010-2011     9
#                                   ..
# Burnley              2009-2010     1
# Newcastle United     2013-2014     1
# Sunderland           2016-2017     1
# Liverpool            2011-2012     1
# Queens Park Rangers  2014-2015     1
# Name: result, Length: 240, dtype: int64

# %%
#top5_teams_t_D=pd.merge(Top5_teams_D_H,Top5_teams_D_A,on='home_team')

# %% [markdown]
# # Premier League top 6 winning home games and scoring over 2.5 goals

# %%
Top6_teams=Top_teams.copy()

# %%
Top6_teams['total_goals']=Top_teams['home_goals'] +Top_teams['away_goals']

# %%
Top6_teams['home_team'].unique()
# Out:
# array(['Sheffield United', 'Arsenal', 'Everton', 'Newcastle United',
#        'Portsmouth', 'Reading', 'West Ham United', 'Bolton Wanderers',
#        'Manchester United', 'Chelsea', 'Watford', 'Tottenham Hotspur',
#        'Aston Villa', 'Manchester City', 'Blackburn Rovers',
#        'Charlton Athletic', 'Fulham', 'Middlesbrough', 'Liverpool',
#        'Wigan Athletic', 'Sunderland', 'Derby County', 'Birmingham City',
#        'Hull City', 'Stoke City', 'West Bromwich Albion',
#        'Wolverhampton Wanderers', 'Burnley', 'Blackpool',
#        'Queens Park Rangers', 'Swansea City', 'Norwich City',
#        'Southampton', 'Crystal Palace', 'Cardiff City', 'Leicester City',
#        'AFC Bournemouth', 'Brighton and Hove Albion', 'Huddersfield Town'],
#       dtype=object)

# %%
Top6_teams=Top6_teams[Top6_teams['total_goals'] >= 3]

# %%
Top6_teams=Top6_teams[(Top6_teams['home_team']=='Liverpool') | (Top6_teams['home_team']=='Chelsea')|(Top6_teams['home_team']=='Manchester City')|(Top6_teams['home_team']=='Manchester United')|(Top6_teams['home_team']=='Tottenham Hotspur')|(Top6_teams['home_team']=='Arsenal')]

# %%
#Top6_teams.groupby(["home_team",'season'])['total_goals'].count().head(60)

# %%
Top6_teams=Top6_teams[Top6_teams['home_goals'] > Top6_teams['away_goals']]

# %%
Top6_teams
# Out:
#               home_team                 away_team  home_goals  away_goals  \
# 8     Manchester United                    Fulham         5.0         1.0
# 9               Chelsea           Manchester City         3.0         0.0
# 18            Liverpool           West Ham United         2.0         1.0
# 31              Chelsea         Charlton Athletic         2.0         1.0
# 49            Liverpool         Tottenham Hotspur         3.0         0.0
# ...                 ...                       ...         ...         ...
# 4532  Manchester United                   Arsenal         2.0         1.0
# 4542            Arsenal                   Burnley         5.0         0.0
# 4547    Manchester City  Brighton and Hove Albion         3.0         1.0
# 4553          Liverpool  Brighton and Hove Albion         4.0         0.0
# 4558  Tottenham Hotspur            Leicester City         5.0         4.0
#
#      result     season  total_goals
# 8         H  2006-2007          6.0
# ...

# %%
Top6_teams
# Out:
#               home_team                 away_team  home_goals  away_goals  \
# 8     Manchester United                    Fulham         5.0         1.0
# 9               Chelsea           Manchester City         3.0         0.0
# 18            Liverpool           West Ham United         2.0         1.0
# 31              Chelsea         Charlton Athletic         2.0         1.0
# 49            Liverpool         Tottenham Hotspur         3.0         0.0
# ...                 ...                       ...         ...         ...
# 4532  Manchester United                   Arsenal         2.0         1.0
# 4542            Arsenal                   Burnley         5.0         0.0
# 4547    Manchester City  Brighton and Hove Albion         3.0         1.0
# 4553          Liverpool  Brighton and Hove Albion         4.0         0.0
# 4558  Tottenham Hotspur            Leicester City         5.0         4.0
#
#      result     season  total_goals
# 8         H  2006-2007          6.0
# ...

# %%
Top6_teams_plt=Top6_teams.groupby(["home_team",'season'])['total_goals'].count().reset_index()

# %%
Top6_teams_plt
# Out:
#             home_team     season  total_goals
# 0             Arsenal  2006-2007           12
# 1             Arsenal  2007-2008            6
# 2             Arsenal  2008-2009            5
# 3             Arsenal  2009-2010           10
# 4             Arsenal  2010-2011            7
# ..                ...        ...          ...
# 67  Tottenham Hotspur  2013-2014            5
# 68  Tottenham Hotspur  2014-2015            8
# 69  Tottenham Hotspur  2015-2016            8
# 70  Tottenham Hotspur  2016-2017           11
# 71  Tottenham Hotspur  2017-2018            5
#
# [72 rows x 3 columns]

# %% [markdown]
# # How many red cards per season for teams

# %%
Top5_stats_cards=Top5_stats.copy()

# %%
Top5_stats
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 2               Liverpool  20.0    10.0   57.0            44.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# ...

# %%
Top5_stats_cards['total_cards']=Top5_stats_cards['total_yel_card'] + Top5_stats_cards['total_red_card']

# %%
#Top5_stats_cards=Top5_stats_cards.groupby(['team','season'])['total_yel_card'].sum()

# %%
Top5_stats_cards
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 2               Liverpool  20.0    10.0   57.0            44.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# ...

# %%
Top5_stats_cards.groupby(['team','season'])['total_cards'].sum().mean()/38
# Out:
# 1.6826754385964913

# %%
Top5_stats_cards['average_cards']=Top5_stats_cards['total_cards']/38

# %%
Top5_stats_cards_av=Top5_stats_cards[Top5_stats_cards['average_cards']>2]

# %%
Top5_stats_cards_av
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 5        Bolton Wanderers  16.0    14.0   47.0            84.0
# 7        Blackburn Rovers  15.0    16.0   52.0            77.0
# 11        West Ham United  12.0    21.0   35.0            85.0
# 27       Blackburn Rovers  15.0    10.0   50.0            72.0
# 33          Middlesbrough  10.0    16.0   43.0            86.0
# 50             Stoke City  12.0    17.0   38.0            73.0
# 53       Blackburn Rovers  10.0    17.0   40.0            74.0
# 72             Sunderland  11.0    16.0   48.0            77.0
# 73       Bolton Wanderers  10.0    19.0   42.0            74.0
# 94       Newcastle United  11.0    14.0   56.0            78.0
# 105               Chelsea  18.0    10.0   65.0            74.0
# 135            Stoke City   9.0    14.0   34.0            78.0
# 150            Stoke City  13.0    14.0   45.0            72.0
# 153           Aston Villa  10.0    20.0   39.0            78.0
# ...

# %%
Top5_stats_cards_av.groupby(["team",'season'])['average_cards'].sum()
# Out:
# team                  season
# Aston Villa           2013-2014    2.052632
#                       2014-2015    2.026316
#                       2015-2016    2.052632
# Blackburn Rovers      2006-2007    2.184211
#                       2007-2008    2.052632
#                       2008-2009    2.052632
# Bolton Wanderers      2006-2007    2.315789
#                       2009-2010    2.078947
# Chelsea               2011-2012    2.052632
#                       2014-2015    2.026316
# Crystal Palace        2016-2017    2.026316
# Hull City             2014-2015    2.078947
# Manchester City       2014-2015    2.078947
# Manchester United     2016-2017    2.105263
# Middlesbrough         2007-2008    2.315789
#                       2016-2017    2.052632
# Newcastle United      2010-2011    2.105263
# Queens Park Rangers   2014-2015    2.052632
# Stoke City            2008-2009    2.052632
#                       2012-2013    2.157895
#                       2013-2014    2.026316
# ...

# %% [markdown]
# # Draws

# %%
Top_teams
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool         1.0         1.0      D
# 1               Arsenal       Aston Villa         1.0         1.0      D
# 2               Everton           Watford         2.0         1.0      H
# 3      Newcastle United    Wigan Athletic         2.0         1.0      H
# 4            Portsmouth  Blackburn Rovers         3.0         0.0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea         3.0         0.0      H
# 4556        Southampton   Manchester City         0.0         1.0      A
# 4557       Swansea City        Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur    Leicester City         5.0         4.0      H
# 4559    West Ham United           Everton         3.0         1.0      H
#
#          season
# 0     2006-2007
# 1     2006-2007
# 2     2006-2007
# 3     2006-2007
# ...

# %%
top_teams_D=Top_teams[Top_teams['result'] == 'D']

# %%
top_teams_D
# Out:
#              home_team                 away_team  home_goals  away_goals  \
# 0     Sheffield United                 Liverpool         1.0         1.0
# 1              Arsenal               Aston Villa         1.0         1.0
# 10             Watford           West Ham United         1.0         1.0
# 13     Manchester City                Portsmouth         0.0         0.0
# 14    Blackburn Rovers                   Everton         1.0         1.0
# ...                ...                       ...         ...         ...
# 4525           Burnley  Brighton and Hove Albion         0.0         0.0
# 4540           Everton               Southampton         1.0         1.0
# 4541   Manchester City         Huddersfield Town         0.0         0.0
# 4545           Chelsea         Huddersfield Town         1.0         1.0
# 4549   West Ham United         Manchester United         0.0         0.0
#
#      result     season
# 0         D  2006-2007
# 1         D  2006-2007
# ...

# %%
top_teams_D.groupby('season')['result'].count().mean()
# Out:
# 97.0

# %%
top_teams_D.groupby('season')['result'].count()
# Out:
# season
# 2006-2007     98
# 2007-2008    100
# 2008-2009     97
# 2009-2010     96
# 2010-2011    111
# 2011-2012     93
# 2012-2013    108
# 2013-2014     78
# 2014-2015     93
# 2015-2016    107
# 2016-2017     84
# 2017-2018     99
# Name: result, dtype: int64

# %%
top_teams_D_H=top_teams_D.groupby(['season','home_team'])['result'].count().reset_index()

# %%
top_teams_D_H
# Out:
#         season             home_team  result
# 0    2006-2007               Arsenal       6
# 1    2006-2007           Aston Villa       8
# 2    2006-2007      Blackburn Rovers       3
# 3    2006-2007      Bolton Wanderers       5
# 4    2006-2007     Charlton Athletic       5
# ..         ...                   ...     ...
# 232  2017-2018          Swansea City       3
# 233  2017-2018     Tottenham Hotspur       4
# 234  2017-2018               Watford       6
# 235  2017-2018  West Bromwich Albion       9
# 236  2017-2018       West Ham United       6
#
# [237 rows x 3 columns]

# %%
top_teams_D_A=top_teams_D.groupby(['season','away_team'])['result'].count().reset_index()

# %%
top_teams_D_A
# Out:
#         season             away_team  result
# 0    2006-2007               Arsenal       5
# 1    2006-2007           Aston Villa       9
# 2    2006-2007      Blackburn Rovers       4
# 3    2006-2007      Bolton Wanderers       3
# 4    2006-2007     Charlton Athletic       5
# ..         ...                   ...     ...
# 235  2017-2018          Swansea City       6
# 236  2017-2018     Tottenham Hotspur       4
# 237  2017-2018               Watford       2
# 238  2017-2018  West Bromwich Albion       4
# 239  2017-2018       West Ham United       6
#
# [240 rows x 3 columns]

# %%
total_draw=pd.merge(top_teams_D_H,top_teams_D_A,on='home_team',how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-257-0a3bce9199d3> in <module>
# ----> 1 total_draw=pd.merge(top_teams_D_H,top_teams_D_A,on='home_team',how='left')
#
# D:\python\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# D:\python\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
# ...

# %%
total_draw['total_count']=total_draw['result_x'] +total_draw['result_y']

# %%
total_draw_g=total_draw.groupby(['season','home_team'])['total_count'].sum().reset_index()

# %%
total_draw
# Out:
#          season        home_team  result_x             away_team  result_y  \
# 0     2006-2007          Arsenal         6               Arsenal         5
# 1     2006-2007          Arsenal         6           Aston Villa         9
# 2     2006-2007          Arsenal         6      Blackburn Rovers         4
# 3     2006-2007          Arsenal         6      Bolton Wanderers         3
# 4     2006-2007          Arsenal         6     Charlton Athletic         5
# ...         ...              ...       ...                   ...       ...
# 4735  2017-2018  West Ham United         6          Swansea City         6
# 4736  2017-2018  West Ham United         6     Tottenham Hotspur         4
# 4737  2017-2018  West Ham United         6               Watford         2
# 4738  2017-2018  West Ham United         6  West Bromwich Albion         4
# 4739  2017-2018  West Ham United         6       West Ham United         6
#
#       total_count
# 0              11
# 1              15
# ...

# %%
total_draw_g
# Out:
#         season             home_team  total_count
# 0    2006-2007               Arsenal          218
# 1    2006-2007           Aston Villa          258
# 2    2006-2007      Blackburn Rovers          158
# 3    2006-2007      Bolton Wanderers          198
# 4    2006-2007     Charlton Athletic          198
# ..         ...                   ...          ...
# 232  2017-2018          Swansea City          159
# 233  2017-2018     Tottenham Hotspur          179
# 234  2017-2018               Watford          219
# 235  2017-2018  West Bromwich Albion          279
# 236  2017-2018       West Ham United          219
#
# [237 rows x 3 columns]

# %%
total_draw_g.groupby(['season','home_team'])['total_count'].sum()
# Out:
# season     home_team
# 2006-2007  Arsenal                 218
#            Aston Villa             258
#            Blackburn Rovers        158
#            Bolton Wanderers        198
#            Charlton Athletic       198
#                                   ...
# 2017-2018  Swansea City            159
#            Tottenham Hotspur       179
#            Watford                 219
#            West Bromwich Albion    279
#            West Ham United         219
# Name: total_count, Length: 237, dtype: int64

# %%
total_draw_g=total_draw_g[total_draw_g['total_count']>150]

# %%
total_draw_g
# Out:
#         season             home_team  total_count
# 0    2006-2007               Arsenal          218
# 1    2006-2007           Aston Villa          258
# 2    2006-2007      Blackburn Rovers          158
# 3    2006-2007      Bolton Wanderers          198
# 4    2006-2007     Charlton Athletic          198
# ..         ...                   ...          ...
# 232  2017-2018          Swansea City          159
# 233  2017-2018     Tottenham Hotspur          179
# 234  2017-2018               Watford          219
# 235  2017-2018  West Bromwich Albion          279
# 236  2017-2018       West Ham United          219
#
# [198 rows x 3 columns]
